# %%
import warnings;
warnings.simplefilter('ignore')

# %% [markdown]
# # 0. Install and Import Deps

# %%
# !pip3 install pystan==2.19.1.1 fbprophet
# Out:
# Requirement already satisfied: pystan==2.19.1.1 in /usr/local/lib/python3.9/site-packages (2.19.1.1)
# Requirement already satisfied: fbprophet in /usr/local/lib/python3.9/site-packages (0.7.1)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.9/site-packages (from pystan==2.19.1.1) (1.21.1)
# Requirement already satisfied: Cython!=0.25.1,>=0.22 in /usr/local/lib/python3.9/site-packages (from pystan==2.19.1.1) (0.29.24)
# Requirement already satisfied: cmdstanpy==0.9.5 in /usr/local/lib/python3.9/site-packages (from fbprophet) (0.9.5)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.9/site-packages (from fbprophet) (1.3.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.9/site-packages (from fbprophet) (3.4.2)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /usr/local/lib/python3.9/site-packages (from fbprophet) (0.0.9)
# Requirement already satisfied: convertdate>=2.1.2 in /usr/local/lib/python3.9/site-packages (from fbprophet) (2.3.2)
# Requirement already satisfied: holidays>=0.10.2 in /usr/local/lib/python3.9/site-packages (from fbprophet) (0.11.2)
# Requirement already satisfied: setuptools-git>=1.2 in /usr/local/lib/python3.9/site-packages (from fbprophet) (1.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.9/site-packages (from fbprophet) (2.8.1)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.9/site-packages (from fbprophet) (4.61.2)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.9/site-packages (from convertdate>=2.1.2->fbprophet) (0.5.11)
# Requirement already satisfied: pytz>=2014.10 in /usr/local/lib/python3.9/site-packages (from convertdate>=2.1.2->fbprophet) (2021.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/site-packages (from holidays>=0.10.2->fbprophet) (1.16.0)
# Requirement already satisfied: hijri-converter in /usr/local/lib/python3.9/site-packages (from holidays>=0.10.2->fbprophet) (2.1.3)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.9/site-packages (from holidays>=0.10.2->fbprophet) (0.2.1)
# Requirement already satisfied: ephem>=3.7.5.3 in /usr/local/lib/python3.9/site-packages (from LunarCalendar>=0.0.9->fbprophet) (4.0.0.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/site-packages (from matplotlib>=2.0.0->fbprophet) (8.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/site-packages (from matplotlib>=2.0.0->fbprophet) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/site-packages (from matplotlib>=2.0.0->fbprophet) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/site-packages (from matplotlib>=2.0.0->fbprophet) (1.3.1)

# %%
import pandas as pd
from fbprophet import Prophet

# %% [markdown]
# # 1. Read in Data and Process Dates

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#    Time Date  Product          Store     Value
# 0    1012018  2667437  QLD_CW_ST0203  2926.000
# 1    2012018  2667437  QLD_CW_ST0203  2687.531
# 2    3012018  2667437  QLD_CW_ST0203  2793.000
# 3    4012018  2667437  QLD_CW_ST0203  2394.000
# 4    5012018  2667437  QLD_CW_ST0203  2660.000

# %%
df.describe()
# Out:
#           Time Date    Product        Value
# count  1.080000e+03     1080.0  1080.000000
# mean   1.567207e+07  2667437.0  4048.117478
# std    8.791548e+06        0.0  1439.945783
# min    1.012018e+06  2667437.0  2042.813500
# 25%    8.069518e+06  2667437.0  2632.498599
# 50%    1.556702e+07  2667437.0  4256.000000
# 75%    2.308452e+07  2667437.0  5288.248910
# max    3.112202e+07  2667437.0  8147.739600

# %%
print(df['Product'].unique())
print(df['Store'].unique())
# Out:
# [2667437]
# ['QLD_CW_ST0203']

# %%
df.dtypes
# Out:
# Time Date      int64
# Product        int64
# Store         object
# Value        float64
# dtype: object

# %%
df['Year'] = df['Time Date'].apply(lambda x: str(x)[-4:])
df['Month'] = df['Time Date'].apply(lambda x: str(x)[-6:-4])
df['Day'] = df['Time Date'].apply(lambda x: str(x)[:-6])
df['ds'] = pd.DatetimeIndex(df['Year'] + '-' + df['Month'] + '-' + df['Day'])

# %%
df.head()
# Out:
#    Time Date  Product          Store     Value  Year Month Day         ds
# 0    1012018  2667437  QLD_CW_ST0203  2926.000  2018    01   1 2018-01-01
# 1    2012018  2667437  QLD_CW_ST0203  2687.531  2018    01   2 2018-01-02
# 2    3012018  2667437  QLD_CW_ST0203  2793.000  2018    01   3 2018-01-03
# 3    4012018  2667437  QLD_CW_ST0203  2394.000  2018    01   4 2018-01-04
# 4    5012018  2667437  QLD_CW_ST0203  2660.000  2018    01   5 2018-01-05

# %%
df.dtypes
# Out:
# Time Date             int64
# Product               int64
# Store                object
# Value               float64
# Year                 object
# Month                object
# Day                  object
# ds           datetime64[ns]
# dtype: object

# %%
df.drop(['Time Date', 'Product', 'Store', 'Year', 'Month', 'Day'], axis=1, inplace=True)
df.columns = ['y', 'ds']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/0c/56kkgk4n2f55xwtb_bh4sknh0000gn/T/ipykernel_94715/517571404.py in <module>
# ----> 1 df.drop(['Time Date', 'Product', 'Store', 'Year', 'Month', 'Day'], axis=1, inplace=True)
#       2 df.columns = ['y', 'ds']
#
# ~/Desktop/study.nosync/data-science/timeseries-forecasting-prophet/tsfbpro/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/Desktop/study.nosync/data-science/timeseries-forecasting-prophet/tsfbpro/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4899                 weight  1.0     0.8
#    4900         """
# -> 4901         return super().drop(
#    4902             labels=labels,
#    4903             axis=axis,
#
# ~/Desktop/study.nosync/data-science/timeseries-forecasting-prophet/tsfbpro/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4145         for axis, labels in axes.items():
#    4146             if labels is not None:
# -> 4147                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4148
#    4149         if inplace:
#
# ~/Desktop/study.nosync/data-science/timeseries-forecasting-prophet/tsfbpro/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4180                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4181             else:
# -> 4182                 new_axis = axis.drop(labels, errors=errors)
#    4183             result = self.reindex(**{axis_name: new_axis})
#    4184
#
# ~/Desktop/study.nosync/data-science/timeseries-forecasting-prophet/tsfbpro/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6016         if mask.any():
#    6017             if errors != "ignore":
# -> 6018                 raise KeyError(f"{labels[mask]} not found in axis")
#    6019             indexer = indexer[~mask]
#    6020         return self.delete(indexer)
#
# KeyError: "['Time Date' 'Product' 'Store' 'Year' 'Month' 'Day'] not found in axis"

# %%
df.head()
# Out:
#           y         ds
# 0  2926.000 2018-01-01
# 1  2687.531 2018-01-02
# 2  2793.000 2018-01-03
# 3  2394.000 2018-01-04
# 4  2660.000 2018-01-05

# %% [markdown]
# # 2. Train Model

# %%
m = Prophet(interval_width=0.95, daily_seasonality=True)
model = m.fit(df)
# Out:
# Initial log joint probability = -33.1653
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       60       1945.54   0.000409428       137.544    4.27e-06       0.001      114  LS failed, Hessian reset
#       99       1946.02    0.00051061       86.4168           1           1      165
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      120       1946.15   0.000797427       127.177   9.132e-06       0.001      222  LS failed, Hessian reset
#      197        1946.2   2.62356e-05       65.8608   3.961e-07       0.001      364  LS failed, Hessian reset
#      199        1946.2   4.49997e-06       59.9822      0.5508      0.5508      366
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      258        1946.2   2.30551e-07       45.2252      0.8962      0.8962      439
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance

# %% [markdown]
# # 3. Forecast Away

# %%
future = m.make_future_dataframe(periods=100, freq='D')
forecast = m.predict(future)
forecast.head()
# Out:
#           ds        trend  yhat_lower   yhat_upper  trend_lower  trend_upper  \
# 0 2018-01-01  3046.999054  875.073769  4006.584906  3046.999054  3046.999054
# 1 2018-01-02  3047.573430  814.136528  4001.519283  3047.573430  3047.573430
# 2 2018-01-03  3048.147805  674.281121  4009.389043  3048.147805  3048.147805
# 3 2018-01-04  3048.722181  837.836410  4109.336397  3048.722181  3048.722181
# 4 2018-01-05  3049.296556  853.966040  4075.942776  3049.296556  3049.296556
#
#    additive_terms  additive_terms_lower  additive_terms_upper       daily  \
# 0     -624.031580           -624.031580           -624.031580  488.234491
# 1     -634.537113           -634.537113           -634.537113  488.234491
# 2     -609.074121           -609.074121           -609.074121  488.234491
# 3     -562.422146           -562.422146           -562.422146  488.234491
# 4     -598.775077           -598.775077           -598.775077  488.234491
#
#    ...     weekly  weekly_lower  weekly_upper       yearly  yearly_lower  \
# 0  ...  16.574517     16.574517     16.574517 -1128.840588  -1128.840588
# 1  ... -11.319356    -11.319356    -11.319356 -1111.452248  -1111.452248
# 2  ...  -4.438156     -4.438156     -4.438156 -1092.870456  -1092.870456
# 3  ...  22.510201     22.510201     22.510201 -1073.166838  -1073.166838
# 4  ... -34.543559    -34.543559    -34.543559 -1052.466009  -1052.466009
#
#    yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0  -1128.840588                   0.0                         0.0
# 1  -1111.452248                   0.0                         0.0
# 2  -1092.870456                   0.0                         0.0
# 3  -1073.166838                   0.0                         0.0
# 4  -1052.466009                   0.0                         0.0
#
#    multiplicative_terms_upper         yhat
# 0                         0.0  2422.967474
# 1                         0.0  2413.036317
# 2                         0.0  2439.073684
# 3                         0.0  2486.300035
# 4                         0.0  2450.521479
#
# [5 rows x 22 columns]

# %%
plot1 = m.plot(forecast)

# %%
plot2 = m.plot_components(forecast)
